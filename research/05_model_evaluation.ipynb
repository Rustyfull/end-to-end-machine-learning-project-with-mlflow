# %%
import  os
os.chdir('..')

# %%
import dagshub
dagshub.init(repo_owner='Rustyfull', repo_name='end-to-end-machine-learning-project-with-mlflow', mlflow=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import dagshub
#       2 dagshub.init(repo_owner='Rustyfull', repo_name='end-to-end-machine-learning-project-with-mlflow', mlflow=True)
#
# ModuleNotFoundError: No module named 'dagshub'
